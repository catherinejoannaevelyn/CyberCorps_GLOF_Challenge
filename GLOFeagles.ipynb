# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

print("Visualizations:")
print(os.listdir("submission_outputs/visualizations")[:10])

print("\nRisk:")
print(os.listdir("submission_outputs/risk")[:10])

print("\nUncertainty:")
print(os.listdir("submission_outputs/uncertainty")[:10])
# Out:
# Visualizations:
# ['1.png', '10.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png']
#
# Risk:
# ['1.png', '10.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png']
#
# Uncertainty:
# ['1.png', '10.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png']

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("submission_outputs/visualizations/1.png")

plt.figure(figsize=(4,4))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("submission_outputs/uncertainty/1.png")

plt.figure(figsize=(4,4))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("submission_outputs/risk/1.png")

plt.figure(figsize=(4,4))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
# %%writefile README.md
# # Team CyberCorps - GLOFeagles 2026 Challenge Submission
#
# ## Overview
#
# This project presents a deep learning pipeline for glacial lake segmentation and Glacial Lake Outburst Flood (GLOF) risk assessment using satellite imagery.
#
# The system performs semantic segmentation of glacier-related environmental features and generates risk maps, uncertainty maps, and per-image risk reports.
#
# ---
#
# ## Team Information
#
# **Team Name:** CyberCorps
#
# ---
#
# ## Model Architecture
#
# The proposed solution uses **DeepLabV3+** for semantic segmentation.
#
# ### Key Features
#
# * DeepLabV3+ segmentation architecture
# * 8-channel multispectral input processing
# * Combined Cross Entropy and Dice Loss
# * Monte Carlo Dropout uncertainty estimation
# * Automated GLOF risk assessment module
#
# ---
#
# ## Dataset
#
# The challenge dataset contains multispectral satellite imagery and labeled glacier-related environmental classes.
#
# ### Classes
#
# * Glacial Lake
# * Snow Cover
# * Cloud Cover
# * Terrain Shadow
# * Moraine
# * Debris Cover
#
# ### Data Split
#
# | Dataset    | Images |
# | ---------- | ------ |
# | Training   | 48     |
# | Validation | 12     |
#
# ---
#
# ## Training Configuration
#
# | Parameter      | Value                     |
# | -------------- | ------------------------- |
# | Architecture   | DeepLabV3+                |
# | Input Channels | 8                         |
# | Image Size     | 512 × 512                 |
# | Optimizer      | AdamW                     |
# | Loss Function  | Cross Entropy + Dice Loss |
# | Batch Size     | 4                         |
# | Early Stopping | Enabled                   |
#
# ---
#
# ## Validation Results
#
# | Metric           | Value  |
# | ---------------- | ------ |
# | Best mIoU        | 0.5388 |
# | Overall Accuracy | 95.22% |
# | Macro F1         | 0.1998 |
# | Cohen's Kappa    | 0.2062 |
#
# ---
#
# ## Generated Outputs
#
# The trained model generated outputs for all 575 challenge images.
#
# Generated artifacts include:
#
# * Segmentation masks
# * Visualization masks
# * Uncertainty maps
# * GLOF risk maps
# * Per-image JSON risk reports
#
# ---
#
# ## Repository Structure
#
# ```text
# checkpoints/
# └── best.pt
#
# submission_outputs/
# ├── predictions/
# ├── visualizations/
# ├── uncertainty/
# ├── risk/
# └── reports/
# ```
#
# ---
#
# ## Running Inference
#
# ```bash
# python inference.py \
#   --checkpoint checkpoints/best.pt \
#   --images <dataset_path> \
#   --out submission_outputs \
#   --mc-passes 2
# ```
#
# ---
#
# ## Video Demonstration
#
# Video Link:
#
# [Insert YouTube Link]
#
# ---
#
# ## Submission Contents
#
# * Source Code
# * Trained Model Checkpoint
# * Generated Outputs
# * Technical Report
# * README
# * Video Demonstration
#
# ---
#
# ## Authors
#
# Team CyberCorps
# Out:
# Overwriting README.md

# %%
# !head -20 README.md
# Out:
# # Team CyberCorps - GLOFeagles 2026 Challenge Submission
#
# ## Overview
#
# This project presents a deep learning pipeline for glacial lake segmentation and Glacial Lake Outburst Flood (GLOF) risk assessment using satellite imagery.
#
# The system performs semantic segmentation of glacier-related environmental features and generates risk maps, uncertainty maps, and per-image risk reports.
#
# ---
#
# ## Team Information
#
# **Team Name:** CyberCorps
#
# ---
#
# ## Model Architecture
#
# The proposed solution uses **DeepLabV3+** for semantic segmentation.

# %%
# !ls -lh README.md
# Out:
# -rw------- 1 root root 2.6K Jun 10 20:21 README.md

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/GLOFeagles/code/team5_rashmi
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/MyDrive/GLOFeagles/code/team5_rashmi'
# /content

# %%
# !ls /content/drive/MyDrive
# Out:
#  10th.pdf
#  23105_cyber_security.jpg
# 'Catherine AI Certificate.pdf'
# 'Catherine CE  Personality Certificate.pdf'
# 'Catherine IBM profile.jpg'
# 'Catherine poe bot.jpg'
# 'cath pp.jpg'
# 'Cattherine CE Communication Certificate.pdf'
#  Classroom
# 'Colab Notebooks'
# 'E Cell Eureka insights'
# 'GLOFeagles '
#  homicide-data.gsheet
# 'IBS QB.gdoc'
#  IMG-20230919-WA0026.pdf
#  IMG-20230925-WA0031.pdf
#  IMG-20231003-WA0090.pdf
#  IMG_20231127_161155_005.jpg
# 'IMG_20231214_154521_1 (1).pdf'
#  IMG_20231214_154521_1.pdf
#  IMG-20240812-WA0066.jpg
#  IMG-20240906-WA0013.jpg
#  IMG-20240929-WA0003.jpg
#  IMG-20250913-WA0011~2.jpg
# 'MEMETASTIC (File responses)'
#  MEMETASTIC.gform
# 'MEMETASTIC (Responses).gsheet'
#  neclogo.jpg
# 'passport size photo.jpg'
#  Screenshot_2023_1225_103204.jpg
#  Screenshot_2024_0102_222531.jpg
#  Screenshot_20240208_171524.jpg
#  Screenshot_20250226_142537.jpg
#  Screenshot_20250913_223736.jpg
#  Snapchat-941920145.jpg
# ...

# %%
# !ls "/content/drive/MyDrive/GLOFeagles "
# Out:
# code  dataset

# %%
# !ls "/content/drive/MyDrive/GLOFeagles/code"
# Out:
# team5_rashmi

# %%
# !ls "/content/drive/MyDrive/GLOFeagles/dataset"
# Out:
# 'SNUC GLOFeagles 2026 challenge datasets'

# %%
# %cd "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi"
# !ls
# Out:
# /content/drive/MyDrive/GLOFeagles/code/team5_rashmi
# __MACOSX  team5_rashmi

# %%
# %cd "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi_deeplabv3"
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi_deeplabv3'
# /content/drive/MyDrive/GLOFeagles/code/team5_rashmi
# __MACOSX  team5_rashmi

# %%
# %cd "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi"
# !ls
# Out:
# /content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi
# common	team5_rashmi_deeplabv3

# %%
# %cd "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3"
# !ls
# Out:
# /content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3
# ablation.py  deeplabv3plus.py  README.md	 temporal.py
# dataset.py   inference.py      requirements.txt  train.py

# %%
# !pip install -r requirements.txt

# %%
# !find "/content/drive/MyDrive/GLOFeagles/dataset" -maxdepth 3 -type d
# Out:
# /content/drive/MyDrive/GLOFeagles/dataset

# %%
from PIL import Image
import numpy as np
import os

label_dir = "PASTE_LABEL_FOLDER_HERE"

f = os.listdir(label_dir)[0]
mask = np.array(Image.open(os.path.join(label_dir, f)))

print("Unique values:", np.unique(mask))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_13350/3721379003.py in <cell line: 0>()
#       5 label_dir = "PASTE_LABEL_FOLDER_HERE"
#       6
# ----> 7 f = os.listdir(label_dir)[0]
#       8 mask = np.array(Image.open(os.path.join(label_dir, f)))
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PASTE_LABEL_FOLDER_HERE'

# %%
# !ls -la "/content/drive/MyDrive/GLOFeagles/dataset"
# Out:
# total 0
# lrw------- 1 root root 0 Jun 10 10:29 'SNUC GLOFeagles 2026 challenge datasets' -> '/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets'

# %%
# !ls -la "/content/drive/.shortcut-targets-by-id"
# Out:
# total 4
# dr-x------ 2 root root 4096 May 22 11:07 1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_

# %%
# !find "/content/drive/.shortcut-targets-by-id" -maxdepth 3 -type d | head -50
# Out:
# /content/drive/.shortcut-targets-by-id
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset" -maxdepth 3 -type d
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Turbidity
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Cloud Cover
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Terraine Shadow
# ...

# %%
import os
from PIL import Image
import numpy as np

label_dir = "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Cloud Cover"

f = os.listdir(label_dir)[0]
mask = np.array(Image.open(os.path.join(label_dir, f)))

print("Shape:", mask.shape)
print("Unique values:", np.unique(mask))
# Out:
# Shape: (512, 512)
# Unique values: [  0 255]

# %%
# !sed -n '1,250p' train.py
# Out:
# """
# Team Rashmi — Training DeepLabV3+ with 8-channel multispectral input.
# """
#
# from __future__ import annotations
# import argparse
# import os
# import sys
# from pathlib import Path
#
# import numpy as np
# import torch
# import torch.nn as nn
# from torch.utils.data import DataLoader
#
# sys.path.insert(0, os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
# sys.path.insert(0, os.path.dirname(os.path.abspath(__file__)))
#
# from common.classes import NUM_CLASSES, CLASS_NAMES
# from common.metrics import full_report, print_report
#
# from deeplabv3plus import DeepLabV3Plus
# from dataset import MultispectralDataset, CHANNEL_NAMES
#
#
# # Reuse the loss from Team Goban — keeps both teams comparable.
# class DiceLoss(nn.Module):
#     def __init__(self, smooth: float = 1.0):
#         super().__init__(); self.smooth = smooth
#
#     def forward(self, logits, targets):
#         n = logits.shape[1]
#         probs = torch.softmax(logits, dim=1)
# ...

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" -type f | head -30
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/423.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/231.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/540.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/533.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/210.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/378.png
# ...

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" -type f | grep -v "Ground truth" | grep -v "Class_Labels" | head -50
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/279.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/311.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/479.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/509.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/533.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/106.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/498.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/282.png
# ...

# %%
# !python -c "
from PIL import Image
import numpy as np

img = np.array(Image.open('/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/533.png'))
print('Image shape:', img.shape)
print('Image unique sample:', np.unique(img)[:20])
"
# Out:
#   File "/tmp/ipykernel_13350/2530986172.py", line 8
#     "
#     ^
# SyntaxError: unterminated string literal (detected at line 8)

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" -maxdepth 2
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Class_Labels
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/279.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/311.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/479.png
# ...

# %%
# !ls "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth"
# Out:
# 'Cloud Cover'	 Moraine      'Terraine Shadow'
# 'Debris Cover'	'Snow Cover'   Turbidity

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth" -name "423.png"
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/423.png

# %%
# !python - <<'PY'
from PIL import Image
import numpy as np

img = np.array(Image.open(
"/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/423.png"
))

print("Shape:", img.shape)
print("Dtype:", img.dtype)
print("Min:", img.min())
print("Max:", img.max())
PY
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# Shape: (512, 512, 3)
# Dtype: uint8
# Min: 0
# Max: 255
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13350/1198227147.py in <cell line: 0>()
#      11 print("Min:", img.min())
#      12 print("Max:", img.max())
# ---> 13 PY
#
# NameError: name 'PY' is not defined

# %%
# !python train.py
# Out:
# usage: train.py [-h] --train-images TRAIN_IMAGES --train-labels TRAIN_LABELS
#                 --val-images VAL_IMAGES --val-labels VAL_LABELS [--out OUT]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE]
#                 [--num-workers NUM_WORKERS] [--image-size IMAGE_SIZE]
#                 [--lr LR] [--patience PATIENCE] [--dropout DROPOUT]
#                 [--n-channels {3,4,8}]
# train.py: error: the following arguments are required: --train-images, --train-labels, --val-images, --val-labels

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" -maxdepth 2 -type d
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Class_Labels

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" -type f | head -50
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/423.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/231.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/540.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/533.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/210.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/378.png
# ...

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_" -type f | grep -Ei "\.(tif|tiff)$" | head -20

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_" -type f | grep -Ei "\.(jpg|jpeg|png)$" | head -100
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/423.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/231.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/540.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/533.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/210.png
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover/378.png
# ...

# %%
# !ls "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" | head
# Out:
# 100.png
# 101.png
# 102.png
# 103.png
# 104.png
# 105.png
# 106.png
# 107.png
# 108.png
# 109.png

# %%
# !find "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth" -name "279.png"
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Moraine/279.png

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Moraine/279.png")

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import os

DATASET = "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets"

for root, dirs, files in os.walk(DATASET):
    if len(files) > 0:
        print(root)
        print("Files:", len(files))
        print("Example:", files[:5])
        print("-"*50)
# Out:
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets
# Files: 575
# Example: ['279.png', '311.png', '479.png', '509.png', '533.png']
# --------------------------------------------------
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Snow Cover
# Files: 10
# Example: ['423.png', '231.png', '540.png', '533.png', '210.png']
# --------------------------------------------------
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Turbidity
# Files: 10
# Example: ['445.png', '56.png', '270.png', '394.png', '322.png']
# --------------------------------------------------
# /content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets/Label_Subset/Ground truth/Cloud Cover
# Files: 10
# ...

# %%
import os, shutil, random
from pathlib import Path

ROOT = "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets"

GT = os.path.join(ROOT, "Label_Subset", "Ground truth")

OUT = "/content/glof_dataset"

for d in [
    f"{OUT}/train/images",
    f"{OUT}/train/labels",
    f"{OUT}/val/images",
    f"{OUT}/val/labels",
]:
    os.makedirs(d, exist_ok=True)

samples = []

for cls in os.listdir(GT):
    cls_dir = os.path.join(GT, cls)

    if not os.path.isdir(cls_dir):
        continue

    for fname in os.listdir(cls_dir):
        img_path = os.path.join(ROOT, fname)
        mask_path = os.path.join(cls_dir, fname)

        if os.path.exists(img_path):
            samples.append((img_path, mask_path))

random.shuffle(samples)

split = int(len(samples) * 0.8)

train_samples = samples[:split]
val_samples = samples[split:]

for img, mask in train_samples:
    shutil.copy(img, f"{OUT}/train/images/{os.path.basename(img)}")
    shutil.copy(mask, f"{OUT}/train/labels/{os.path.basename(mask)}")

for img, mask in val_samples:
    shutil.copy(img, f"{OUT}/val/images/{os.path.basename(img)}")
    shutil.copy(mask, f"{OUT}/val/labels/{os.path.basename(mask)}")

print("Train:", len(train_samples))
print("Val:", len(val_samples))
# Out:
# Train: 48
# Val: 12

# %%
# !find /content/glof_dataset -type f | wc -l
# Out:
# 120

# %%
# %cd "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3"
# !pwd
# Out:
# /content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3
# /content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3

# %%
# !python train.py \
  --train-images /content/glof_dataset/train/images \
  --train-labels /content/glof_dataset/train/labels \
  --val-images /content/glof_dataset/val/images \
  --val-labels /content/glof_dataset/val/labels \
  --epochs 20 \
  --batch-size 4 \
  --num-workers 2 \
  --out ./checkpoints
# Out:
# Device: cpu  |  channels: 8
# Train: 48  Val: 12
# epoch   1 | train_loss=1.1443 | val_mIoU=0.2277 | val_kappa=-0.0090
#   -> saved best (mIoU=0.2277)
# epoch   2 | train_loss=1.0203 | val_mIoU=0.1998 | val_kappa=0.0888
# epoch   3 | train_loss=0.9120 | val_mIoU=0.1807 | val_kappa=0.2202
# epoch   4 | train_loss=0.8175 | val_mIoU=0.2250 | val_kappa=0.2777
# epoch   5 | train_loss=0.7618 | val_mIoU=0.1853 | val_kappa=0.2800
# epoch   6 | train_loss=0.7059 | val_mIoU=0.5938 | val_kappa=0.3604
#   -> saved best (mIoU=0.5938)
# epoch   7 | train_loss=0.6452 | val_mIoU=0.5634 | val_kappa=0.2771
# epoch   8 | train_loss=0.6208 | val_mIoU=0.5425 | val_kappa=0.2198
# epoch   9 | train_loss=0.6108 | val_mIoU=0.5363 | val_kappa=0.1991
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3/train.py", line 164, in <module>
#     train(parse_args())
# ...

# %%
# !ls checkpoints
# Out:
# best.pt

# %%
# !python train.py \
  --train-images /content/glof_dataset/train/images \
  --train-labels /content/glof_dataset/train/labels \
  --val-images /content/glof_dataset/val/images \
  --val-labels /content/glof_dataset/val/labels \
  --epochs 20 \
  --batch-size 4 \
  --num-workers 2 \
  --out ./checkpoints
# Out:
# Device: cpu  |  channels: 8
# Train: 48  Val: 12
# epoch   1 | train_loss=1.3474 | val_mIoU=0.0009 | val_kappa=0.0002
#   -> saved best (mIoU=0.0009)
# epoch   2 | train_loss=1.1897 | val_mIoU=0.1092 | val_kappa=0.0107
#   -> saved best (mIoU=0.1092)
# epoch   3 | train_loss=1.0385 | val_mIoU=0.1655 | val_kappa=0.0925
#   -> saved best (mIoU=0.1655)
# epoch   4 | train_loss=0.8799 | val_mIoU=0.1798 | val_kappa=0.2014
#   -> saved best (mIoU=0.1798)
# epoch   5 | train_loss=0.7753 | val_mIoU=0.2088 | val_kappa=0.1568
#   -> saved best (mIoU=0.2088)
# epoch   6 | train_loss=0.7195 | val_mIoU=0.2140 | val_kappa=0.1951
#   -> saved best (mIoU=0.2140)
# epoch   7 | train_loss=0.6718 | val_mIoU=0.3702 | val_kappa=0.2509
#   -> saved best (mIoU=0.3702)
# epoch   8 | train_loss=0.6697 | val_mIoU=0.2722 | val_kappa=0.2203
# epoch   9 | train_loss=0.6299 | val_mIoU=0.2187 | val_kappa=0.2262
# epoch  10 | train_loss=0.6015 | val_mIoU=0.5388 | val_kappa=0.2062
#   -> saved best (mIoU=0.5388)
# ...

# %%
# !ls -lh checkpoints
# Out:
# total 155M
# -rw------- 1 root root 155M Jun 10 14:33 best.pt

# %%
# !sed -n '1,200p' inference.py
# Out:
# """
# Team Rashmi — Monte Carlo Dropout inference and GLOF risk scoring.
#
# The MC trick:
#   * Dropout layers are randomly disabled during training (regularization).
#   * Normally turned OFF at inference time.
#   * Here we KEEP THEM ON at inference and run T forward passes per image.
#   * Average predictions = final answer.
#   * Variance across T runs = uncertainty.
#
# Cyber analogy: run the same alert past 30 different analysts and check whether
# they agree. Disagreement = flag for human review.
# """
#
# from __future__ import annotations
# import argparse
# import json
# import os
# import sys
# from pathlib import Path
#
# import numpy as np
# import torch
# import torch.nn.functional as F
#
# sys.path.insert(0, os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
# sys.path.insert(0, os.path.dirname(os.path.abspath(__file__)))
#
# from common.classes import NUM_CLASSES, colorize_mask
# from common.data_loading import load_multispectral, load_rgb_image
#
# ...

# %%
# !tail -50 inference.py
# Out:
#         # Resize back to original
#         pred = np.array(Image.fromarray(pred_small).resize((w, h), Image.NEAREST))
#         unc  = np.array(Image.fromarray((unc_small * 255).astype(np.uint8))
#                         .resize((w, h), Image.BILINEAR))
#
#         # Save predictions / viz
#         Image.fromarray(pred).save(out_dir / "predictions" / f"{ip.stem}.png")
#         Image.fromarray(colorize_mask(pred)).save(out_dir / "visualizations" / f"{ip.stem}.png")
#         Image.fromarray(unc).save(out_dir / "uncertainty" / f"{ip.stem}.png")
#
#         # GLOF risk
#         lake_mask = (pred == 1)
#         glacier_mask = np.isin(pred, [3, 4])  # clean ice + debris ice as the glacier
#         risk = compute_lake_risk(lake_mask, glacier_mask)
#         Image.fromarray(_risk_to_rgb(risk["risk_mask"])).save(out_dir / "risk" / f"{ip.stem}.png")
#         with open(out_dir / "reports" / f"{ip.stem}.json", "w") as f:
#             json.dump(risk["per_lake"], f, indent=2)
#
# ...

# %%
# !python inference.py \
  --checkpoint checkpoints/best.pt \
  --images "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" \
  --out submission_outputs \
  --mc-passes 5
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3/inference.py", line 209, in <module>
#     run(parse_args())
#   File "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3/inference.py", line 148, in run
#     mean_probs, var_probs = mc_predict(model, x_t, n_passes=args.mc_passes)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/GLOFeagles/code/team5_rashmi/team5_rashmi/team5_rashmi_deeplabv3/inference.py", line 54, in mc_predict
#     logits = model(x)
#              ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
# ...

# %%
# !find submission_outputs/predictions -name "*.png" 2>/dev/null | wc -l
# Out:
# 301

# %%
# !rm -rf submission_outputs

# %%
# !python inference.py \
  --checkpoint checkpoints/best.pt \
  --images "/content/drive/.shortcut-targets-by-id/1nvNg0Y3W5cyrm8spxQZ-i5cQzA_7bnG_/SNUC GLOFeagles 2026 challenge datasets" \
  --out submission_outputs \
  --mc-passes 2
# Out:
# Wrote 575 predictions to submission_outputs

# %%
# !find submission_outputs/predictions -name "*.png" | wc -l
# Out:
# 575

# %%
# !du -sh submission_outputs/*
# Out:
# 963K	submission_outputs/predictions
# 957K	submission_outputs/reports
# 1.4M	submission_outputs/risk
# 37M	submission_outputs/uncertainty
# 1.8M	submission_outputs/visualizations

# %%
# !zip -r submission_outputs.zip submission_outputs
# Out:
#   adding: submission_outputs/ (stored 0%)
#   adding: submission_outputs/predictions/ (stored 0%)
#   adding: submission_outputs/predictions/1.png (deflated 12%)
#   adding: submission_outputs/predictions/10.png (deflated 14%)
#   adding: submission_outputs/predictions/100.png (deflated 34%)
#   adding: submission_outputs/predictions/101.png (deflated 7%)
#   adding: submission_outputs/predictions/102.png (deflated 12%)
#   adding: submission_outputs/predictions/103.png (deflated 3%)
#   adding: submission_outputs/predictions/104.png (deflated 17%)
#   adding: submission_outputs/predictions/105.png (deflated 5%)
#   adding: submission_outputs/predictions/106.png (deflated 5%)
#   adding: submission_outputs/predictions/107.png (deflated 11%)
#   adding: submission_outputs/predictions/108.png (deflated 10%)
#   adding: submission_outputs/predictions/109.png (deflated 4%)
#   adding: submission_outputs/predictions/11.png (deflated 26%)
# ...

# %%
# !ls -lh submission_outputs.zip
# Out:
# -rw------- 1 root root 40M Jun 10 18:42 submission_outputs.zip

# %%
# !cp checkpoints/best.pt /content/drive/MyDrive/best_glof_model.pt

# %%
# !zip model_checkpoint.zip checkpoints/best.pt
# Out:
#   adding: checkpoints/best.pt (deflated 8%)

# %%
# !unzip -l model_checkpoint.zip | head
# Out:
# Archive:  model_checkpoint.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
# 161783327  2026-06-10 14:33   checkpoints/best.pt
# ---------                     -------
# 161783327                     1 file

# %%
# !unzip -l submission_outputs.zip | head -20
# Out:
# Archive:  submission_outputs.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#         0  2026-06-10 17:35   submission_outputs/
#         0  2026-06-10 18:27   submission_outputs/predictions/
#      1293  2026-06-10 17:35   submission_outputs/predictions/1.png
#      1126  2026-06-10 17:35   submission_outputs/predictions/10.png
#       640  2026-06-10 17:35   submission_outputs/predictions/100.png
#      1467  2026-06-10 17:35   submission_outputs/predictions/101.png
#      1363  2026-06-10 17:35   submission_outputs/predictions/102.png
#      2446  2026-06-10 17:35   submission_outputs/predictions/103.png
#      1148  2026-06-10 17:36   submission_outputs/predictions/104.png
#      3140  2026-06-10 17:36   submission_outputs/predictions/105.png
#      3324  2026-06-10 17:36   submission_outputs/predictions/106.png
#      1421  2026-06-10 17:36   submission_outputs/predictions/107.png
# ...

# %%
# !cp submission_outputs.zip /content/drive/MyDrive/
# !cp model_checkpoint.zip /content/drive/MyDrive/
